.jpg\r\nhttp://farm1.static.flickr.com/26/65718856_4be779e500.jpg\r\nhttp://fotos.marktplaats.nl/kopen/f/8b/6Q4MaZriXniv1oBjpJwyEQ==.jpg\r\nhttp://farm1.static.flickr.com/234/524353354_1c582c147f.jpg\r\nhttp://farm4.static.flickr.com/3175/2495236674_02e57c97de.jpg\r\nhttp://www.freephoto1.com/photo/photo-bicycle.jpg\r\nhttp://farm1.static.flickr.com/39/123467197_8888d4194f.jpg\r\nhttp://gizmodo.com/gadgets/images/bmc_cnt_bike.jpg\r\nhttp://static.flickr.com/79/276360647_65ff1ced3d.jpg\r\nhttp://farm1.static.flickr.com/21/24613090_737ddffe11.jpg\r\nhttp://farm1.static.flickr.com/45/178890059_00a6550475.jpg\r\nhttp://graphics8.nytimes.com/images/2007/07/10/nyregion/bike600.gif\r\nhttp://sta ...

# %% [markdown]
# Import ResNet Arch

# %%
str_ships_soup=str(ships_soup)#convert soup to string so it can be split
type(str_ships_soup)
ships_split_urls=str_ships_soup.split('\r\n')#split so each url is a different possition on a list
print("The length of the ships list is ",len(ships_split_urls))#print the length of the list so you know how many urls you have

bikes_str_soup=str(bikes_soup)#convert soup to string so it can be split
type(bikes_str_soup)
bikes_split_urls=bikes_str_soup.split('\r\n')#split so each url is a different possition on a list
print("The length of the bikes list is ", len(bikes_split_urls))
# Out:
# The length of the ships list is  1262
# The length of the bikes list is  1345

# %%
class ResnetIdentityBlock(tf.keras.Model):
  def __init__(self, kernel_size, filters):
    super(ResnetIdentityBlock, self).__init__(name='')
    filters1, filters2, filters3 = filters

    self.conv2a = tf.keras.layers.Conv2D(filters1, (1, 1))
    self.bn2a = tf.keras.layers.BatchNormalization()

    self.conv2b = tf.keras.layers.Conv2D(filters2, kernel_size, padding='same')
    self.bn2b = tf.keras.layers.BatchNormalization()

    self.conv2c = tf.keras.layers.Conv2D(filters3, (1, 1))
    self.bn2c = tf.keras.layers.BatchNormalization()

  def call(self, input_tensor, training=False):
    x = self.conv2a(input_tensor)
    x = self.bn2a(x, training=training)
    x = tf.nn.relu(x)

    x = self.conv2b(x)
    x = self.bn2b(x, training=training)
    x = tf.nn.relu(x)

    x = self.conv2c(x)
    x = self.bn2c(x, training=training)

    x += input_tensor
    return tf.nn.relu(x)

# %% [markdown]
# Make training and validation directories

# %%
# !mkdir /content/train 
# !mkdir /content/train/ships 
# !mkdir /content/train/bikes 
# !mkdir /content/validation
# !mkdir /content/validation/ships 
# !mkdir /content/validation/bikes

# %% [markdown]
# Correct the images shape, format, and store them on the corresponding directory

# %%
img_rows, img_cols = 2224, 2224 
input_shape = (img_rows, img_cols, 3)
# Out:
# TRAIN:
#
#
# list the files inside ships directory:
#
# img0.jpg    img260.jpg	img391.jpg  img550.jpg	img69.jpg   img839.jpg
# img102.jpg  img262.jpg	img394.jpg  img551.jpg	img690.jpg  img841.jpg
# img103.jpg  img264.jpg	img395.jpg  img552.jpg	img691.jpg  img842.jpg
# img105.jpg  img265.jpg	img396.jpg  img554.jpg	img692.jpg  img843.jpg
# img111.jpg  img139.jpg	img165.jpg  img190.jpg	img37.jpg  img63.jpg  img92.jpg
# img112.jpg  img14.jpg	img166.jpg  img191.jpg	img38.jpg  img65.jpg  img93.jpg
# img114.jpg  img140.jpg	img167.jpg  img192.jpg	img39.jpg  img66.jpg  img94.jpg
# img115.jpg  img141.jpg	img168.jpg  img193.jpg	img4.jpg   img67.jpg  img95.jpg
# img116.jpg  img142.jpg	img169.jpg  img194.jpg	img40.jpg  img68.jpg  img96.jpg
# img117.jpg  img143.jpg	img17.jpg   img195.jpg	img41.jpg  img69.jpg  img97.jpg
# img119.jpg  img144.jpg	img170.jpg  img196.jpg	img43.jpg  img7.jpg   img98.jpg
# img12.jpg   img145.jpg	img171.jpg  img197.jpg	img44.jpg  img70.jpg  img99.jpg
# img120.jpg  img146.jpg	img172.jpg  img198.jpg	img45.jpg  img72.jpg
# img121.jpg  img147.jpg	img173.jpg  img199.jpg	img46.jpg  img73.jpg
# img122.jpg  img148.jpg	img174.jpg  img2.jpg	img47.jpg  img74.jpg
# img123.jpg  img149.jpg	img175.jpg  img20.jpg	img49.jpg  img75.jpg
# img124.jpg  img15.jpg	img177.jpg  img23.jpg	img5.jpg   img76.jpg

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255,
                                   rotation_range=50,
                                   horizontal_flip=True,
                                   brightness_range=(0.5,1.5),
                                   zoom_range=0.5,
                                   fill_mode='nearest')
                                   
validation_datagen = ImageDataGenerator(rescale=1/255)

# %% [markdown]
# Building the model:

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras import backend as K

# create the base pre-trained model
base_model = InceptionV3(weights='imagenet', include_top=False)

# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)
# and a logistic layer -- let's say we have 200 classes
predictions = Dense(1, activation='sigmoid')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable = False



model.compile(loss='binary_crossentropy',
              optimizer='RMSprop',
             metrics=['acc'])
train_generator = train_datagen.flow_from_directory(
        '/data/content/train/',
        target_size=(224, 224),
        batch_size=40,
        class_mode='binary')

validation_generator = validation_datagen.flow_from_directory(
        '/data/content/validation/',  
        target_size=(224, 224),  
        batch_size=20,
        class_mode='binary')
model.fit_generator(
    train_generator,
    steps_per_epoch=10,
    epochs=30,
    verbose=1,
    validation_data=validation_generator,
    validation_steps=5
  )
# Out:
# Found 1270 images belonging to 2 classes.
# Found 348 images belonging to 2 classes.
# Epoch 1/30
# 10/10 [==============================] - 5s 537ms/step - loss: 1.7145 - acc: 0.7575 - val_loss: 0.0710 - val_acc: 0.9900
# Epoch 2/30
# 10/10 [==============================] - 5s 455ms/step - loss: 0.1073 - acc: 0.9550 - val_loss: 0.0063 - val_acc: 1.0000
# Epoch 3/30
# 10/10 [==============================] - 5s 461ms/step - loss: 0.3231 - acc: 0.9075 - val_loss: 0.5488 - val_acc: 0.8600
# Epoch 4/30
# 10/10 [==============================] - 4s 441ms/step - loss: 0.2670 - acc: 0.9179 - val_loss: 0.1823 - val_acc: 0.9500
# Epoch 5/30
# Epoch 26/30
# 10/10 [==============================] - 5s 462ms/step - loss: 0.0658 - acc: 0.9795 - val_loss: 0.0995 - val_acc: 0.9800
# Epoch 27/30
# 10/10 [==============================] - 5s 464ms/step - loss: 0.1649 - acc: 0.9500 - val_loss: 0.0136 - val_acc: 0.9900
# Epoch 28/30
# 10/10 [==============================] - 5s 453ms/step - loss: 0.0859 - acc: 0.9725 - val_loss: 0.0331 - val_acc: 0.9800
# Epoch 29/30
# 10/10 [==============================] - 4s 447ms/step - loss: 0.1725 - acc: 0.9564 - val_loss: 0.1219 - val_acc: 0.9600
# Epoch 30/30
# 10/10 [==============================] - 5s 459ms/step - loss: 0.1858 - acc: 0.9525 - val_loss: 0.0036 - val_acc: 1.0000

# %%
plt.imshow(PIL.Image.open("/data/content/validation/ships/img11.jpg"))

# %%
from tensorflow.keras.preprocessing import image

img_path='/data/content/validation/ships/img11.jpg'
img = image.load_img(img_path, target_size=(200, 200))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.
plt.imshow(img_tensor[0])
plt.show()

# %%
layer_outputs = [layer.output for layer in model.layers[:13]]
activation_model = tf.keras.models.Model(inputs = model.input, outputs = layer_outputs)
activations = activation_model.predict(img_tensor)

# %%
layer_names = []
for layer in model.layers[:8]:
    layer_names.append(layer.name)
    
images_per_row = 20

for layer_name, layer_activation in zip(layer_names, activations):
    n_features = layer_activation.shape[-1] 
    print(size)
    size = layer_activation.shape[1] 
    n_cols = n_features // images_per_row 
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    for col in range(n_cols): 
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            channel_image -= channel_image.mean() 
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size, 
                         row * size : (row + 1) * size] = channel_image
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='plasma')
# Out:
# 200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-e8eac5acf19a> in <module>
#      25     scale = 1. / size
#      26     plt.figure(figsize=(scale * display_grid.shape[1],
# ---> 27                         scale * display_grid.shape[0]))
#      28     plt.title(layer_name)
#      29     plt.grid(False)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     544                                         frameon=frameon,
#     545                                         FigureClass=FigureClass,
# --> 546                                         **kwargs)
#     547
#     548         if figLabel:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3334         from matplotlib.figure import Figure
#    3335         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3336         fig = fig_cls(*args, **kwargs)
#    3337         return cls.new_figure_manager_given_figure(num, fig)
#    3338
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in __init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout)
#     347
#     348         if not np.isfinite(figsize).all() or (np.array(figsize) <= 0).any():
# --> 349             raise ValueError('figure size must be positive finite not '
#     350                              f'{figsize}')
#     351         self.bbox_inches = Bbox.from_bounds(0, 0, *figsize)
#
# ValueError: figure size must be positive finite not (20.0, 0.0)
